# %% [markdown]
# # UNET 8x8 3D de Carlos
# Este modelo UNET ha sido entrenado con todas las imágenes del dataset imagenes_etiquetadas_8x8-002.csv de todas las turbinas.

# %% [markdown]
# ## **Importación**

# %%
# Data manipulation
import pandas as pd
import numpy as np

#Data Split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize

#Neuronal Network API
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import *
from tensorflow.keras.regularizers import l2

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.colors as mcolors

import os
import collections
from google.colab import drive

# %%
# %matplotlib inline
print(plt.style.available)
plt.style.use('seaborn-v0_8')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Lectura**

# %%
df_columns = pd.read_csv('/content/drive/MyDrive/TFG_modelado/datasets/imagenes_etiquetadas_8x8-002.csv', nrows=1)

# %%
variables = ['Amb_WindSpeed_Avg', 'Grd_Prod_Pwr_Avg', 'Blds_PitchAngle']
variables_id = ['Id', 'Fecha_Inicio', 'Fecha_Fin', 'label']

columns_read = [col for col in df_columns.columns if any([v in col for v in variables + variables_id])]
df = pd.read_csv('/content/drive/MyDrive/TFG_modelado/datasets/imagenes_etiquetadas_8x8-002.csv', usecols=columns_read)

# %%
df
# Out:
#         Id         Fecha_Inicio            Fecha_Fin  label  \
# 0        1  2009-07-08 15:20:00  2009-07-09 02:30:00      5
# 1        1  2009-07-09 02:30:00  2009-07-09 13:10:00      0
# 2        1  2009-07-09 13:10:00  2009-07-09 23:50:00      5
# 3        1  2009-07-09 23:50:00  2009-07-10 10:30:00      0
# 4        1  2009-07-10 10:30:00  2009-07-10 21:10:00      5
# ...     ..                  ...                  ...    ...
# 791350  25  2017-03-08 03:20:00  2017-03-08 14:00:00      0
# 791351  25  2017-03-08 14:00:00  2017-03-09 00:40:00      0
# 791352  25  2017-03-09 00:40:00  2017-03-09 11:20:00      0
# 791353  25  2017-03-09 11:20:00  2017-03-09 22:00:00      0
# 791354  25  2017-03-09 22:00:00  2017-03-10 08:40:00      0
#
#         Amb_WindSpeed_Avg_1  Amb_WindSpeed_Avg_2  Amb_WindSpeed_Avg_3  \
# 0                       0.4                  0.4                  0.4
# 1                       5.6                  5.9                  5.9
# 2                       4.1                  3.6                  5.8
# 3                       3.3                  3.3                  2.9
# 4                       3.6                  3.7                  4.7
# ...                     ...                  ...                  ...
# 791350                  5.6                  6.0                  6.6
# 791351                  3.5                  3.8                  3.8
# 791352                  3.5                  3.4                  3.2
# 791353                  5.5                  6.4                  6.1
# 791354                  6.9                  6.7                  6.4
#
#         Amb_WindSpeed_Avg_4  Amb_WindSpeed_Avg_5  Amb_WindSpeed_Avg_6  ...  \
# 0                       0.4                  0.4                  0.4  ...
# 1                       6.6                  5.6                  5.4  ...
# 2                       6.7                  6.0                  5.0  ...
# 3                       2.6                  2.7                  2.7  ...
# 4                       4.2                  5.5                  2.6  ...
# ...                     ...                  ...                  ...  ...
# 791350                  8.1                  7.8                  8.3  ...
# 791351                  3.6                  3.0                  3.3  ...
# 791352                  3.5                  4.0                  3.9  ...
# 791353                  5.6                  6.1                  5.8  ...
# 791354                  6.7                  6.9                  7.1  ...
#
#         Blds_PitchAngle_Avg_55  Blds_PitchAngle_Avg_56  \
# 0                         89.4                    89.4
# 1                         89.4                    89.4
# 2                         89.5                    89.5
# 3                         43.1                    57.6
# 4                         86.0                    86.0
# ...                        ...                     ...
# 791350                    24.0                    24.0
# 791351                    -0.6                    15.2
# 791352                    24.0                     4.9
# 791353                    -2.2                    -2.2
# 791354                    24.0                    24.0
#
#         Blds_PitchAngle_Avg_57  Blds_PitchAngle_Avg_58  \
# 0                         89.4                    89.4
# 1                         89.4                    89.4
# 2                         89.5                    89.5
# 3                         77.9                    79.0
# 4                         86.0                    86.0
# ...                        ...                     ...
# 791350                    24.0                    24.0
# 791351                    24.0                    24.0
# 791352                    -0.6                    -0.4
# 791353                    -2.2                    -2.1
# 791354                    24.0                    19.8
#
#         Blds_PitchAngle_Avg_59  Blds_PitchAngle_Avg_60  \
# 0                         89.4                    89.4
# 1                         89.4                    89.4
# 2                         89.5                    89.5
# 3                         79.7                    89.4
# 4                         86.0                    86.0
# ...                        ...                     ...
# 791350                    12.8                    14.5
# 791351                    24.0                    24.0
# 791352                     0.0                     0.0
# 791353                    -2.0                    -2.0
# 791354                    10.9                     0.3
#
#         Blds_PitchAngle_Avg_61  Blds_PitchAngle_Avg_62  \
# 0                         89.4                    89.4
# 1                         89.4                    89.4
# 2                         89.5                    89.5
# 3                         89.5                    89.5
# 4                         86.0                    86.0
# ...                        ...                     ...
# 791350                    17.3                    13.0
# 791351                    24.0                    24.0
# 791352                    -0.8                    -0.6
# 791353                    -2.0                    -2.0
# 791354                    -0.3                     0.0
#
#         Blds_PitchAngle_Avg_63  Blds_PitchAngle_Avg_64
# 0                         89.4                    89.4
# 1                         89.4                    89.4
# 2                         89.5                    89.5
# 3                         84.4                    65.3
# 4                         86.0                    86.0
# ...                        ...                     ...
# 791350                    18.4                    -0.1
# 791351                    24.0                    24.0
# 791352                    -0.3                    -1.2
# 791353                    -1.9                    -2.0
# 791354                    10.8                    24.0
#
# [791355 rows x 196 columns]

# %%
print(collections.Counter(df['label']))
# Out:
# Counter({0: 678981, -1: 57424, 1: 44104, 5: 5157, 2: 3532, 3: 2157})

# %% [markdown]
# ## **Preprocesado**

# %%
df['label'] = df['label'] + 1
df.loc[(df['label']==6),'label'] = 5
y_train = df['label'].values

# %%
y_train.shape
# Out:
# (791355,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
values = scaler.fit_transform(df[[col for col in df.columns if any([v in col for v in variables])]].values)

# %%
values_swap = np.swapaxes(values.reshape(-1,3,8,8),1,3)

# %%
values_swap.shape
# Out:
# (791355, 8, 8, 3)

# %%
X_train = values_swap

# %%
counters = collections.Counter(df['label'])
print(counters)
# Out:
# Counter({1: 678981, 0: 57424, 2: 44104, 5: 5157, 3: 3532, 4: 2157})

# %% [markdown]
# **Balanceo de los datos para el entrenaminento**

# %%
from collections import deque
import numpy as np
#Se corresponden con las labels antiguas mas 1
count0 = 0
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0

mode = 'balanced'
samples = (counters[3]+counters[4]+counters[5])

lists = deque()
list_grid = deque()
label_list = deque()
for i in range(X_train.shape[0]):
    if mode=='balanced':
        #Cojo un 5% mas de las etiquetas 0 y 1 (-1 y 0 respectivamente)
        if(df.loc[i,'label']==0 and count0<(0.7*samples)):
            lists.append(X_train[i])
            label_list.append(df.loc[i, 'label'])
            count0+=1
        if(df.loc[i,'label']==1 and count1<(0.7*samples)):
            lists.append(X_train[i])
            label_list.append(df.loc[i, 'label'])
            count1+=1
        if(df.loc[i,'label']==2 and count2<(0.7*samples)):
            lists.append(X_train[i])
            label_list.append(df.loc[i, 'label'])
            count2+=1
        if(df.loc[i,'label']==3 and count3<samples):
            lists.append(X_train[i])
            label_list.append(df.loc[i, 'label'])
            count3+=1
        if(df.loc[i,'label']==4 and count4<samples):
            lists.append(X_train[i])
            label_list.append(df.loc[i, 'label'])
            count4+=1
        if(df.loc[i,'label']==5 and count5<(0.7*samples)):
            lists.append(X_train[i])
            label_list.append(df.loc[i, 'label'])
            count5+=1
    else:
        lists.append(X_train[i])
        label_list.append(df.loc[i, 'label'])

X_train = np.array(lists)
y_train = np.array(label_list)

# %%
print(collections.Counter(y_train))
# Out:
# Counter({1: 7593, 2: 7593, 0: 7593, 5: 5157, 3: 3532, 4: 2157})

# %%
X_train.shape
# Out:
# (33625, 8, 8, 3)

# %%
X_train =  tf.image.resize_with_pad(X_train, 16, 16, method='bicubic')
X_train = X_train.numpy().astype('float32')

# %%
y_train = tf.keras.utils.to_categorical(y_train,num_classes=6)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.1, shuffle=True, random_state=16)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, shuffle=True, random_state=42)

# %% [markdown]
# ## **Modelo**

# %%
def build_model(input_layer=Input((16,16,3)), start_neurons=16):
    """Define la arquitectura U-Net"""
    drop_rate_hidden = 0.4

    #Convolution
    conv1 = Conv2D(start_neurons * 4, (3, 3),activation='relu',padding="same",name='EncodeConv1_1')(input_layer)
    conv1 = Dropout(drop_rate_hidden)(conv1)
    conv1 = Conv2D(start_neurons * 4, (3, 3),activation='relu',padding="same",name='EncodeConv1_2')(conv1)
    pool1 = MaxPooling2D((2, 2),name='EncodeAveragePool1')(conv1)


    # Convolution2
    conv2 = Conv2D(start_neurons * 8, (3, 3),activation='relu',padding="same",name='BridgeConv_1')(pool1)
    conv2 = Dropout(drop_rate_hidden)(conv2)
    conv2 = Conv2D(start_neurons * 8, (3, 3),activation='relu',padding="same",name='BridgeConv_2')(conv2)

    pool2= MaxPooling2D((1, 2),name='EncodeAveragePool2')(conv2)

    #Convolution3 (3er nivel)
    conv3 = Conv2D(start_neurons * 16, (3, 3),activation='relu',padding="same",name='BridgeConv_3')(pool2)
    conv3 = Dropout(drop_rate_hidden)(conv3)
    conv3 = Conv2D(start_neurons * 16, (3, 3),activation='relu',padding="same",name='BridgeConv_4')(conv3)

    pool3= MaxPooling2D((2, 1),name='EncodeAveragePool3')(conv3)


    #Convolution4 (4º nivel)
    conv4 = Conv2D(start_neurons * 32, (3, 3),activation='relu',padding="same",name='BridgeConv_5')(pool3)
    conv4 = Dropout(drop_rate_hidden)(conv4)
    conv4 = Conv2D(start_neurons * 32, (3, 3),activation='relu',padding="same",name='BridgeConv_6')(conv4)

    #Upsampling3
    deconv3 = Conv2DTranspose(start_neurons * 16, (3, 3), strides=(2, 1), padding="same",name='DecodeUp3')(conv4)

    uconv3 = concatenate([deconv3, conv3], axis=3,name='Concat3')

    uconv3 = Conv2D(start_neurons * 16, (3, 3),activation='relu',padding="same",name='DecodeConv3_1')(uconv3)
    uconv3 = Dropout(drop_rate_hidden)(uconv3)
    uconv3 = Conv2D(start_neurons * 16, (3, 3),activation='relu',padding="same",name='DecodeConv3_2')(uconv3)


    #Upsampling2
    deconv2 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(1, 2), padding="same",name='DecodeUp2')(uconv3)

    uconv2 = concatenate([deconv2, conv2], axis=3,name='Concat2')

    uconv2 = Conv2D(start_neurons * 8, (3, 3),activation='relu',padding="same",name='DecodeConv2_1')(uconv2)
    uconv2 = Dropout(drop_rate_hidden)(uconv2)
    uconv2 = Conv2D(start_neurons * 8, (3, 3),activation='relu',padding="same",name='DecodeConv2_2')(uconv2)


    #Upsampling1

    deconv1 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same",name='DecodeUp1')(uconv2)
    uconv1 = concatenate([deconv1, conv1], axis=3,name='Concat1')

    uconv1 = Conv2D(start_neurons * 4, (3, 3),activation='relu',padding="same",name='DecodeConv1_1')(uconv1)
    uconv1 = Dropout(drop_rate_hidden)(uconv1)
    uconv1 = Conv2D(start_neurons * 4, (3, 3),activation='relu',padding="same",name='DecodeConv1_2')(uconv1)


    #Aplanamiento de los tensores

    uconv1 = Flatten(name='Flattening')(uconv1)


    dense1 = Dense(64,activation='relu')(uconv1)
    dense1 = Dropout(drop_rate_hidden)(dense1)

    dense2 = Dense(32,activation='relu')(dense1)
    dense2 = Dropout(drop_rate_hidden)(dense2)



    output_layer = Dense(6, activation="softmax",name='Classifier')(dense2)

    unet = tf.keras.Model(input_layer, output_layer,name='UNet')

    return unet

# %%
unet = build_model()

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-8)


unet.compile(optimizer=tf.keras.optimizers.Nadam()
, loss="categorical_crossentropy", metrics=['accuracy','Precision'])

# %%
history = unet.fit(X_train, y_train, batch_size=128, validation_data=(X_val,y_val), callbacks=[reduce_lr,early_stopping], epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 178/178 [==============================] - 34s 76ms/step - loss: 1.2814 - accuracy: 0.4778 - precision: 0.7543 - val_loss: 1.1589 - val_accuracy: 0.5205 - val_precision: 0.8298 - lr: 0.0010
# Epoch 2/100
# 178/178 [==============================] - 10s 58ms/step - loss: 1.3433 - accuracy: 0.5871 - precision: 0.7842 - val_loss: 0.6265 - val_accuracy: 0.7400 - val_precision: 0.8630 - lr: 0.0010
# Epoch 3/100
# 178/178 [==============================] - 10s 56ms/step - loss: 0.7068 - accuracy: 0.7236 - precision: 0.8150 - val_loss: 0.4595 - val_accuracy: 0.8362 - val_precision: 0.8892 - lr: 0.0010
# Epoch 4/100
# 178/178 [==============================] - 11s 60ms/step - loss: 0.5858 - accuracy: 0.7770 - precision: 0.8399 - val_loss: 0.3611 - val_accuracy: 0.8684 - val_precision: 0.8966 - lr: 0.0010
# Epoch 5/100
# 178/178 [==============================] - 10s 57ms/step - loss: 0.5125 - accuracy: 0.8091 - precision: 0.8549 - val_loss: 0.3753 - val_accuracy: 0.8832 - val_precision: 0.9011 - lr: 0.0010
# Epoch 6/100
# 178/178 [==============================] - 10s 58ms/step - loss: 0.4739 - accuracy: 0.8267 - precision: 0.8625 - val_loss: 0.3132 - val_accuracy: 0.8914 - val_precision: 0.9161 - lr: 0.0010
# Epoch 7/100
# 178/178 [==============================] - 10s 58ms/step - loss: 0.4188 - accuracy: 0.8517 - precision: 0.8834 - val_loss: 0.3081 - val_accuracy: 0.8990 - val_precision: 0.9109 - lr: 0.0010
# Epoch 8/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.4055 - accuracy: 0.8539 - precision: 0.8851 - val_loss: 0.5053 - val_accuracy: 0.7955 - val_precision: 0.8082 - lr: 0.0010
# Epoch 9/100
# 178/178 [==============================] - 11s 60ms/step - loss: 0.3965 - accuracy: 0.8598 - precision: 0.8877 - val_loss: 0.2767 - val_accuracy: 0.8973 - val_precision: 0.9049 - lr: 0.0010
# Epoch 10/100
# 178/178 [==============================] - 11s 59ms/step - loss: 0.3712 - accuracy: 0.8682 - precision: 0.8935 - val_loss: 0.3079 - val_accuracy: 0.8939 - val_precision: 0.9018 - lr: 0.0010
# Epoch 11/100
# 178/178 [==============================] - 11s 62ms/step - loss: 0.3444 - accuracy: 0.8783 - precision: 0.9012 - val_loss: 0.2639 - val_accuracy: 0.9089 - val_precision: 0.9159 - lr: 0.0010
# Epoch 12/100
# 178/178 [==============================] - 11s 60ms/step - loss: 0.3372 - accuracy: 0.8839 - precision: 0.9069 - val_loss: 0.2276 - val_accuracy: 0.9178 - val_precision: 0.9265 - lr: 0.0010
# Epoch 13/100
# 178/178 [==============================] - 10s 59ms/step - loss: 0.3838 - accuracy: 0.8693 - precision: 0.8926 - val_loss: 0.4244 - val_accuracy: 0.8060 - val_precision: 0.8251 - lr: 0.0010
# Epoch 14/100
# 178/178 [==============================] - 11s 60ms/step - loss: 0.3407 - accuracy: 0.8776 - precision: 0.8987 - val_loss: 0.2322 - val_accuracy: 0.9161 - val_precision: 0.9240 - lr: 0.0010
# Epoch 15/100
# 178/178 [==============================] - 10s 58ms/step - loss: 0.3296 - accuracy: 0.8812 - precision: 0.9007 - val_loss: 0.2640 - val_accuracy: 0.9042 - val_precision: 0.9199 - lr: 0.0010
# Epoch 16/100
# 178/178 [==============================] - 11s 59ms/step - loss: 0.3111 - accuracy: 0.8903 - precision: 0.9097 - val_loss: 0.2139 - val_accuracy: 0.9239 - val_precision: 0.9318 - lr: 0.0010
# Epoch 17/100
# 178/178 [==============================] - 11s 60ms/step - loss: 0.3292 - accuracy: 0.8882 - precision: 0.9082 - val_loss: 0.3484 - val_accuracy: 0.8590 - val_precision: 0.8864 - lr: 0.0010
# Epoch 18/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.3147 - accuracy: 0.8908 - precision: 0.9133 - val_loss: 0.2431 - val_accuracy: 0.9146 - val_precision: 0.9229 - lr: 0.0010
# Epoch 19/100
# 178/178 [==============================] - 11s 59ms/step - loss: 0.3161 - accuracy: 0.8902 - precision: 0.9083 - val_loss: 0.2270 - val_accuracy: 0.9186 - val_precision: 0.9297 - lr: 0.0010
# Epoch 20/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2894 - accuracy: 0.8968 - precision: 0.9135 - val_loss: 0.2281 - val_accuracy: 0.9185 - val_precision: 0.9257 - lr: 0.0010
# Epoch 21/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2841 - accuracy: 0.8974 - precision: 0.9128 - val_loss: 0.2140 - val_accuracy: 0.9245 - val_precision: 0.9323 - lr: 0.0010
# Epoch 22/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2375 - accuracy: 0.9175 - precision: 0.9318 - val_loss: 0.1817 - val_accuracy: 0.9366 - val_precision: 0.9417 - lr: 1.0000e-04
# Epoch 23/100
# 178/178 [==============================] - 10s 58ms/step - loss: 0.2263 - accuracy: 0.9199 - precision: 0.9325 - val_loss: 0.1791 - val_accuracy: 0.9367 - val_precision: 0.9417 - lr: 1.0000e-04
# Epoch 24/100
# 178/178 [==============================] - 11s 59ms/step - loss: 0.2207 - accuracy: 0.9223 - precision: 0.9342 - val_loss: 0.1816 - val_accuracy: 0.9358 - val_precision: 0.9415 - lr: 1.0000e-04
# Epoch 25/100
# 178/178 [==============================] - 11s 62ms/step - loss: 0.2180 - accuracy: 0.9254 - precision: 0.9363 - val_loss: 0.1794 - val_accuracy: 0.9375 - val_precision: 0.9451 - lr: 1.0000e-04
# Epoch 26/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2205 - accuracy: 0.9237 - precision: 0.9349 - val_loss: 0.1838 - val_accuracy: 0.9376 - val_precision: 0.9438 - lr: 1.0000e-04
# Epoch 27/100
# 178/178 [==============================] - 10s 59ms/step - loss: 0.2203 - accuracy: 0.9222 - precision: 0.9349 - val_loss: 0.1845 - val_accuracy: 0.9352 - val_precision: 0.9417 - lr: 1.0000e-04
# Epoch 28/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2149 - accuracy: 0.9263 - precision: 0.9377 - val_loss: 0.1828 - val_accuracy: 0.9351 - val_precision: 0.9405 - lr: 1.0000e-04
# Epoch 29/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2108 - accuracy: 0.9242 - precision: 0.9363 - val_loss: 0.1751 - val_accuracy: 0.9372 - val_precision: 0.9430 - lr: 1.0000e-05
# Epoch 30/100
# 178/178 [==============================] - 11s 62ms/step - loss: 0.2141 - accuracy: 0.9248 - precision: 0.9369 - val_loss: 0.1740 - val_accuracy: 0.9392 - val_precision: 0.9448 - lr: 1.0000e-05
# Epoch 31/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2102 - accuracy: 0.9265 - precision: 0.9376 - val_loss: 0.1735 - val_accuracy: 0.9391 - val_precision: 0.9446 - lr: 1.0000e-05
# Epoch 32/100
# 178/178 [==============================] - 11s 59ms/step - loss: 0.2063 - accuracy: 0.9274 - precision: 0.9381 - val_loss: 0.1745 - val_accuracy: 0.9384 - val_precision: 0.9440 - lr: 1.0000e-05
# Epoch 33/100
# 178/178 [==============================] - 10s 58ms/step - loss: 0.2043 - accuracy: 0.9283 - precision: 0.9398 - val_loss: 0.1753 - val_accuracy: 0.9376 - val_precision: 0.9431 - lr: 1.0000e-05
# Epoch 34/100
# 178/178 [==============================] - 11s 59ms/step - loss: 0.2039 - accuracy: 0.9290 - precision: 0.9395 - val_loss: 0.1742 - val_accuracy: 0.9393 - val_precision: 0.9445 - lr: 1.0000e-05
# Epoch 35/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2079 - accuracy: 0.9268 - precision: 0.9374 - val_loss: 0.1750 - val_accuracy: 0.9381 - val_precision: 0.9436 - lr: 1.0000e-05
# Epoch 36/100
# 178/178 [==============================] - 11s 62ms/step - loss: 0.2058 - accuracy: 0.9292 - precision: 0.9395 - val_loss: 0.1749 - val_accuracy: 0.9389 - val_precision: 0.9439 - lr: 1.0000e-05
# Epoch 37/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2056 - accuracy: 0.9269 - precision: 0.9372 - val_loss: 0.1745 - val_accuracy: 0.9384 - val_precision: 0.9434 - lr: 1.0000e-06
# Epoch 38/100
# 178/178 [==============================] - 11s 61ms/step - loss: 0.2055 - accuracy: 0.9290 - precision: 0.9391 - val_loss: 0.1745 - val_accuracy: 0.9383 - val_precision: 0.9438 - lr: 1.0000e-06
# Epoch 39/100
# 178/178 [==============================] - 10s 59ms/step - loss: 0.2070 - accuracy: 0.9295 - precision: 0.9402 - val_loss: 0.1744 - val_accuracy: 0.9385 - val_precision: 0.9434 - lr: 1.0000e-06
# Epoch 40/100
# 178/178 [==============================] - 10s 59ms/step - loss: 0.2085 - accuracy: 0.9268 - precision: 0.9366 - val_loss: 0.1746 - val_accuracy: 0.9381 - val_precision: 0.9429 - lr: 1.0000e-06
# Epoch 41/100
# 178/178 [==============================] - 11s 62ms/step - loss: 0.2067 - accuracy: 0.9288 - precision: 0.9400 - val_loss: 0.1748 - val_accuracy: 0.9380 - val_precision: 0.9434 - lr: 1.0000e-06

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.savefig('model_accuracy_3D_8x8.pdf', bbox_inches = 'tight')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.ylim(0,1)
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.savefig('model_precision_3D_8x8.pdf', bbox_inches = 'tight')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.savefig('model_loss_3D_8x8.pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# **Matriz de confusión**

# %%
from sklearn import metrics

labels = [0, 1, 2, 3, 4, 5]
predictions = unet.predict(X_test)
# Calcula la matriz de confusión
confusion_matrix = metrics.confusion_matrix(y_test.argmax(axis=1), predictions.argmax(axis=1))
confusion_matrix = confusion_matrix / confusion_matrix.sum(axis=1, keepdims=True)

# Configura y muestra la matriz de confusión
plt.figure(figsize=(10, 8))
plt.title('Matriz de Confusión')
plt.xlabel('Predicciones')
plt.ylabel('Etiquetas Verdaderas')

for i in range(len(labels)):
    for j in range(len(labels)):
        text_color = "white" if confusion_matrix[i, j] > 0.5 else "black"  # Color blanco si el valor es alto
        plt.text(j, i, format(confusion_matrix[i, j], ".3f"),
                 ha="center", va="center", color=text_color, fontsize=12)

plt.imshow(confusion_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.colorbar()
plt.xticks(ticks=np.arange(len(labels)), labels=labels)
plt.yticks(ticks=np.arange(len(labels)), labels=labels)
plt.grid(False)  # Desactiva las líneas de la cuadrícula

plt.savefig('confusionMatrix_3D_8x8.pdf', bbox_inches = 'tight')

plt.show()
# Out:
# 106/106 [==============================] - 2s 11ms/step

# %% [markdown]
# **Se guarda el modelo de etiquetado UNET para su posterior inferencia**

# %%
# Guarda el modelo tanto los pesos como la arquitectura con formato .h5
unet.save('unet_8x8_3D_Carlos.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Se prueba a cargar el mismo modelo, con su arquitectura y pesos para la inferencia
load_model = tf.keras.models.load_model('unet_8x8_3D_Carlos.h5')
results = load_model.evaluate(X_test, y_test)
loss = results[0]
acc = results[1]
print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))
# Out:
# 106/106 [==============================] - 2s 10ms/step - loss: 0.1732 - accuracy: 0.9450 - precision: 0.9492
# Restored model, accuracy: 94.50%

# %%
predictions = load_model.predict(X_test)
# Out:
# 106/106 [==============================] - 1s 6ms/step

# %%
print(predictions.shape)
probabilidades = predictions[0]
# Normaliza las probabilidades para que sumen 1 (probabilidad total)
probabilidades_normalizadas = probabilidades / np.sum(probabilidades)

print("Probabilidades normalizadas en formato decimal de la primera imagen del test set:\n")
for i, probabilidad in enumerate(probabilidades_normalizadas):
    print("["+str(i)+"]: " + "{:.4f}".format(probabilidad))

etiquetas_predichas = np.argmax(predictions, axis=1)

print("\nEtiquetas predichas:")
print(etiquetas_predichas)
# Out:
# (3363, 6)
# Probabilidades normalizadas en formato decimal de la primera imagen del test set:
#
# [0]: 0.0000
# [1]: 0.0005
# [2]: 0.9995
# [3]: 0.0001
# [4]: 0.0000
# [5]: 0.0000
#
# Etiquetas predichas:
# [2 3 3 ... 1 4 0]

# %% [markdown]
# ## **Generación del dataset completo de etiquetas**
# - Se genera el dataset y se almacena en un .csv con el formato "etiqueta", "Id"; siendo "Id" el de la turbina eólica.

# %%
df_columns = pd.read_csv('/content/drive/MyDrive/TFG_modelado/datasets/imagenes_etiquetadas_8x8-002.csv', nrows=1)
variables = ['Amb_WindSpeed_Avg', 'Grd_Prod_Pwr_Avg', 'Blds_PitchAngle']
variables_id = ['Id', 'Fecha_Inicio', 'Fecha_Fin', 'label']

columns_read = [col for col in df_columns.columns if any([v in col for v in variables + variables_id])]
df = pd.read_csv('/content/drive/MyDrive/TFG_modelado/datasets/imagenes_etiquetadas_8x8-002.csv', usecols=columns_read)

# %%
print(collections.Counter(df['label']))
# Out:
# Counter({0: 678981, -1: 57424, 1: 44104, 5: 5157, 2: 3532, 3: 2157})

# %%
df['label'] = df['label'] + 1
df.loc[(df['label']==6),'label'] = 5
y_train = df['label'].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
values = scaler.fit_transform(df[[col for col in df.columns if any([v in col for v in variables])]].values)

# %%
# Obtener la lista de IDs únicos de las turbinas
unique_ids = df['Id'].unique()
lote = 10000

# Crear un DataFrame vacío para almacenar las predicciones
df_prec = pd.DataFrame(columns=['etiqueta_rendimiento', 'Id'])

# Iterar sobre los IDs de las turbinas
for id_turbina in unique_ids:
    print(f"Generando datos de Turbina [{id_turbina}]")

    df_turbina = df[df['Id'] == id_turbina]  # Filtrar el DataFrame por la turbina actual

    values = scaler.transform(df_turbina[[col for col in df_turbina.columns if any([v in col for v in variables])]].values)
    values_swap = np.swapaxes(values.reshape(-1,3,8,8),1,3)

    X_train = values_swap
    counters = collections.Counter(df_turbina['label'])

    print(X_train.shape)
    print(counters)

    # Se preprocesan X_train y y_train
    X_train =  tf.image.resize_with_pad(X_train, 16, 16, method='bicubic')
    X_train = X_train.numpy().astype('float32')

    predictions3D = unet.predict(X_train)

    etiquetas_predichas = np.argmax(predictions3D, axis=1)

    df_turbina_prec = pd.DataFrame({'etiqueta_rendimiento': etiquetas_predichas})
    df_turbina_prec['Id'] = id_turbina  # Agregar ID correspondiente a la turbina actual

    # Concatenar el DataFrame de la turbina actual al DataFrame general
    df_prec = pd.concat([df_prec, df_turbina_prec], ignore_index=True)

# Verificar información del DataFrame resultante
df_prec.info()
# Out:
# Generando datos de Turbina [1]
# (31167, 8, 8, 3)
# Counter({1: 26480, 0: 3685, 2: 743, 5: 164, 4: 76, 3: 19})
# 974/974 [==============================] - 6s 7ms/step
# Generando datos de Turbina [2]
# (43740, 8, 8, 3)
# Counter({1: 39202, 2: 2934, 0: 818, 5: 424, 3: 227, 4: 135})
# 1367/1367 [==============================] - 9s 7ms/step
# Generando datos de Turbina [3]
# (37473, 8, 8, 3)
# Counter({1: 31280, 2: 4539, 0: 1001, 3: 391, 5: 159, 4: 103})
# 1172/1172 [==============================] - 8s 7ms/step
# Generando datos de Turbina [4]
# (31246, 8, 8, 3)
# Counter({1: 26644, 0: 2876, 2: 1314, 5: 270, 3: 71, 4: 71})
# 977/977 [==============================] - 6s 6ms/step
# Generando datos de Turbina [5]
# (30933, 8, 8, 3)
# Counter({1: 26432, 0: 2677, 2: 1308, 5: 294, 3: 145, 4: 77})
# 967/967 [==============================] - 6s 6ms/step
# Generando datos de Turbina [6]
# (36950, 8, 8, 3)
# Counter({1: 32247, 0: 3420, 2: 1017, 5: 126, 3: 70, 4: 70})
# 1155/1155 [==============================] - 7s 6ms/step
# Generando datos de Turbina [7]
# (30868, 8, 8, 3)
# Counter({1: 27542, 2: 1434, 0: 1421, 5: 259, 3: 135, 4: 77})
# 965/965 [==============================] - 7s 7ms/step
# Generando datos de Turbina [8]
# (36942, 8, 8, 3)
# Counter({1: 32455, 2: 3654, 0: 289, 3: 279, 5: 172, 4: 93})
# 1155/1155 [==============================] - 7s 6ms/step
# Generando datos de Turbina [9]
# (36847, 8, 8, 3)
# Counter({1: 34134, 2: 1290, 0: 1128, 5: 178, 4: 69, 3: 48})
# 1152/1152 [==============================] - 7s 6ms/step
# Generando datos de Turbina [10]
# (30600, 8, 8, 3)
# Counter({1: 23492, 2: 6015, 3: 619, 5: 268, 4: 157, 0: 49})
# 957/957 [==============================] - 6s 6ms/step
# Generando datos de Turbina [11]
# (24711, 8, 8, 3)
# Counter({1: 19859, 2: 3917, 3: 425, 5: 180, 4: 171, 0: 159})
# 773/773 [==============================] - 5s 7ms/step
# Generando datos de Turbina [12]
# (24737, 8, 8, 3)
# Counter({1: 20127, 0: 4091, 2: 354, 5: 86, 4: 56, 3: 23})
# 774/774 [==============================] - 4s 6ms/step
# Generando datos de Turbina [13]
# (24841, 8, 8, 3)
# Counter({1: 23208, 0: 828, 2: 567, 5: 127, 4: 82, 3: 29})
# 777/777 [==============================] - 5s 7ms/step
# Generando datos de Turbina [14]
# (37265, 8, 8, 3)
# Counter({1: 30722, 0: 5701, 5: 369, 2: 352, 4: 89, 3: 32})
# 1165/1165 [==============================] - 8s 7ms/step
# Generando datos de Turbina [15]
# (30979, 8, 8, 3)
# Counter({1: 25429, 0: 4725, 2: 488, 5: 219, 4: 74, 3: 44})
# 969/969 [==============================] - 6s 6ms/step
# Generando datos de Turbina [16]
# (31017, 8, 8, 3)
# Counter({1: 26917, 2: 3278, 0: 432, 5: 163, 3: 132, 4: 95})
# 970/970 [==============================] - 6s 6ms/step
# Generando datos de Turbina [17]
# (37022, 8, 8, 3)
# Counter({1: 30268, 0: 4797, 2: 1390, 5: 400, 4: 112, 3: 55})
# 1157/1157 [==============================] - 8s 7ms/step
# Generando datos de Turbina [18]
# (30745, 8, 8, 3)
# Counter({1: 25339, 0: 4312, 2: 800, 5: 193, 4: 72, 3: 29})
# 961/961 [==============================] - 6s 7ms/step
# Generando datos de Turbina [19]
# (24655, 8, 8, 3)
# Counter({1: 21484, 0: 2251, 2: 645, 5: 181, 4: 54, 3: 40})
# 771/771 [==============================] - 5s 6ms/step
# Generando datos de Turbina [20]
# (43001, 8, 8, 3)
# Counter({1: 37701, 2: 3320, 0: 1486, 5: 218, 3: 164, 4: 112})
# 1344/1344 [==============================] - 8s 6ms/step
# Generando datos de Turbina [21]
# (24542, 8, 8, 3)
# Counter({1: 20930, 0: 2877, 2: 528, 5: 113, 4: 69, 3: 25})
# 767/767 [==============================] - 4s 6ms/step
# Generando datos de Turbina [22]
# (18483, 8, 8, 3)
# Counter({1: 15760, 0: 2435, 2: 161, 5: 67, 4: 37, 3: 23})
# 578/578 [==============================] - 4s 7ms/step
# Generando datos de Turbina [23]
# (30861, 8, 8, 3)
# Counter({1: 28490, 0: 1293, 2: 744, 5: 184, 3: 78, 4: 72})
# 965/965 [==============================] - 6s 6ms/step
# Generando datos de Turbina [24]
# (24690, 8, 8, 3)
# Counter({1: 21285, 0: 2992, 2: 180, 5: 169, 4: 47, 3: 17})
# 772/772 [==============================] - 5s 7ms/step
# Generando datos de Turbina [25]
# (37040, 8, 8, 3)
# Counter({1: 31554, 2: 3132, 0: 1681, 3: 412, 5: 174, 4: 87})
# 1158/1158 [==============================] - 8s 7ms/step
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 791355 entries, 0 to 791354
# Data columns (total 2 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   etiqueta_rendimiento  791355 non-null  object
#  1   Id                    791355 non-null  object
# dtypes: object(2)
# memory usage: 12.1+ MB

# %%
conteo_valores = df_prec['etiqueta_rendimiento'].value_counts()

print("Conteo de valores de cada clase:")
print(conteo_valores)
# Out:
# Conteo de valores de cada clase:
# 1    609051
# 0     93226
# 2     72229
# 5      6730
# 3      6602
# 4      3517
# Name: etiqueta_rendimiento, dtype: int64

# %%
coincidencias = 0

# Iterar sobre las filas utilizando zip
for etiqueta_df1, etiqueta_df2 in zip(df['label'], df_prec['etiqueta_rendimiento']):
    if etiqueta_df1 == etiqueta_df2:
        coincidencias += 1

# %%
print("Coincidencias etiquetas predichas y reales: " + str(coincidencias))
print(len(df))
print(len(df_prec))
# Out:
# Coincidencias etiquetas predichas y reales: 715502
# 791355
# 791355

# %%
# Guardamos el dataset de etiquetas predichas

# %%
df_prec.to_csv('etiq_Carlos_8x8_3D_prediccion.csv', index=False)
